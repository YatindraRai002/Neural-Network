# %% [markdown]
# <a href="https://colab.research.google.com/github/YatindraRai002/Neural-Network/blob/main/fasshion_mnist.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf

print("TensorFlow imported.")
# Out:
# TensorFlow imported.

# %%
from tensorflow.keras.datasets import fashion_mnist

(x_train, y_train), (x_test, y_test) = fashion_mnist.load_data()

print(f"x_train shape: {x_train.shape}")
print(f"y_train shape: {y_train.shape}")
print(f"x_test shape: {x_test.shape}")
print(f"y_test shape: {y_test.shape}")
# Out:
# ...
# 29515/29515 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# ...
# 26421880/26421880 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# ...
# 5148/5148 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# ...
# 4422102/4422102 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# x_train shape: (60000, 28, 28)
# y_train shape: (60000,)
# x_test shape: (10000, 28, 28)
# y_test shape: (10000,)

# %%
import numpy as np

# Convert data type to float32
x_train = x_train.astype('float32')
x_test = x_test.astype('float32')

print("Data types converted to float32.")

# Normalize pixel values to the range [0, 1]
x_train = x_train / 255.0
x_test = x_test / 255.0

print("Pixel values normalized to [0, 1].")

# Reshape images to include a channel dimension (for grayscale, this is 1)
x_train = np.expand_dims(x_train, -1)
x_test = np.expand_dims(x_test, -1)

print(f"x_train shape after reshaping: {x_train.shape}")
print(f"x_test shape after reshaping: {x_test.shape}")

# One-hot encode the labels
y_train = tf.keras.utils.to_categorical(y_train, num_classes=10)
y_test = tf.keras.utils.to_categorical(y_test, num_classes=10)

print(f"y_train shape after one-hot encoding: {y_train.shape}")
print(f"y_test shape after one-hot encoding: {y_test.shape}")
# Out:
# Data types converted to float32.
# Pixel values normalized to [0, 1].
# x_train shape after reshaping: (60000, 28, 28, 1)
# x_test shape after reshaping: (10000, 28, 28, 1)
# y_train shape after one-hot encoding: (60000, 10)
# y_test shape after one-hot encoding: (10000, 10)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense

# Initialize a Sequential model
model = Sequential()

# Add the first Conv2D layer
model.add(Conv2D(32, (3, 3), activation='relu', input_shape=(28, 28, 1)))
# Add the first MaxPooling2D layer
model.add(MaxPooling2D((2, 2)))

# Add the second Conv2D layer
model.add(Conv2D(64, (3, 3), activation='relu'))
# Add the second MaxPooling2D layer
model.add(MaxPooling2D((2, 2)))


model.add(Flatten())

model.add(Dense(128, activation='relu'))

# Add the final Dense output layer with 10 units for 10 classes and softmax activation
model.add(Dense(10, activation='softmax'))


model.summary()
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/convolutional/base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                 │ (None, 26, 26, 32)     │           320 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 13, 13, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# ...

# %%
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

print("Model compiled successfully with Adam optimizer, categorical crossentropy loss, and accuracy metric.")
# Out:
# Model compiled successfully with Adam optimizer, categorical crossentropy loss, and accuracy metric.

# %%
history = model.fit(x_train, y_train, epochs=10, batch_size=32, validation_data=(x_test, y_test))

print("Model training complete. Training history stored in 'history' variable.")
# Out:
# Epoch 1/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 71s 37ms/step - accuracy: 0.7794 - loss: 0.6104 - val_accuracy: 0.8601 - val_loss: 0.3715
# Epoch 2/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 66s 35ms/step - accuracy: 0.8842 - loss: 0.3191 - val_accuracy: 0.8914 - val_loss: 0.3009
# Epoch 3/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 82s 35ms/step - accuracy: 0.9050 - loss: 0.2576 - val_accuracy: 0.8958 - val_loss: 0.2834
# Epoch 4/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 66s 35ms/step - accuracy: 0.9150 - loss: 0.2305 - val_accuracy: 0.9053 - val_loss: 0.2672
# Epoch 5/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 67s 36ms/step - accuracy: 0.9291 - loss: 0.1934 - val_accuracy: 0.9054 - val_loss: 0.2621
# Epoch 6/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 69s 37ms/step - accuracy: 0.9365 - loss: 0.1716 - val_accuracy: 0.9091 - val_loss: 0.2590
# Epoch 7/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 79s 35ms/step - accuracy: 0.9409 - loss: 0.1564 - val_accuracy: 0.9089 - val_loss: 0.2530
# Epoch 8/10
# ...

# %%
model.predict(x_test)
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step
# array([[1.34301092e-09, 6.72814914e-15, 1.30767308e-09, ...,
#         4.43514800e-05, 1.02868460e-11, 9.99954760e-01],
#        [4.27144222e-08, 1.43298350e-18, 9.99999821e-01, ...,
#         1.43299983e-18, 6.07106947e-16, 6.77839481e-18],
#        [3.42289738e-12, 9.99999940e-01, 3.90309184e-18, ...,
#         3.64654290e-33, 1.12052626e-18, 5.86661705e-25],
#        ...,
#        [2.03704501e-11, 2.05922159e-15, 1.75793069e-13, ...,
#         7.19216184e-15, 9.99999940e-01, 6.23779216e-17],
#        [3.31197786e-12, 9.99999940e-01, 4.32053959e-12, ...,
#         8.81384369e-21, 3.76982028e-13, 1.99878869e-18],
#        [1.45351233e-08, 6.21205474e-12, 1.24392330e-09, ...,
#         2.47714233e-05, 1.13821514e-07, 5.59440494e-08]], dtype=float32)

# %%
model.evaluate(x_test, y_test)
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.9083 - loss: 0.3151
# [0.29935207962989807, 0.9097999930381775]
